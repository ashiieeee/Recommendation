# %%
# !pip install -qq convokit

# %%
# !pip install -qq scikit-surprise

# %%
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
import convokit

# %%
# Load the Cornell Movie Dialogs Corpus
corpus = convokit.Corpus(filename=convokit.download("movie-corpus"))
# Out:
# Downloading movie-corpus to C:\Users\ashit\.convokit\downloads\movie-corpus
# Downloading movie-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip (40.9MB)... Done

# %%
# Display basic statistics
print("Number of conversations:", len(corpus.conversations))
print("Number of users:", len(corpus.speakers))
print("Number of utterances:", len(corpus.utterances))
# Out:
# Number of conversations: 83097
# Number of users: 9035
# Number of utterances: 304713

# %%
# Display information about conversations
for convo_id in corpus.get_conversation_ids():
    convo = corpus.get_conversation(convo_id)
    print("Conversation ID:", convo_id)
    print("Metadata:", convo.meta)
    print("Number of utterances in conversation:", len(convo.get_utterance_ids()))
    print()
# Out:
# Conversation ID: L1044
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L984
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L924
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L870
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L866
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L862
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L860
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L696
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L693
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L662
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L577
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L575
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L404
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L401
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L367
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L365
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L363
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L280
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L276
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L271
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L207
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L204
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L200
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L198
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L952
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L659
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L598
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L595
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L579
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L571
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L49
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L759
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L756
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L592
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L589
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L396
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L394
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L1051
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L1021
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L1007
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L982
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L909
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L904
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L901
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L893
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L889
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L655
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L601
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L542
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L531
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L529
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L525
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L441
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L319
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L164
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L922
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L878
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L544
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L538
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L536
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L523
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L517
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L189
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L179
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L458
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L778
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L583
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L499
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L432
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L424
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L416
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L388
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L244
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L223
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L215
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L212
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L210
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L157
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L143
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L139
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L87
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L77
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L66
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L63
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L780
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L743
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L740
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L725
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L623
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L621
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L619
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L430
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L426
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L411
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L385
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L557
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L554
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L335
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L148
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L747
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L607
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L605
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L354
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L349
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L300
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L298
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L294
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L287
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L285
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L508
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L502
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L238
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L231
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L946
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L750
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L716
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L490
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L447
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L252
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L247
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L151
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L133
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L131
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L129
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L123
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L1040
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L1033
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L1031
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L973
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L960
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L957
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L936
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L852
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L842
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L834
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L828
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L824
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L813
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L808
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L803
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L800
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L798
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L769
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L764
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L686
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L683
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L680
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L677
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L670
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L668
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L650
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L639
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L626
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L612
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L610
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L564
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L481
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L475
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L473
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L333
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L330
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L322
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L311
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L309
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L304
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L998
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L989
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L986
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L338
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L184
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L172
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L1017
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L108
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L103
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L735
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L732
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L728
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L775
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L723
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L436
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L428
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L420
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L414
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L383
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L380
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L378
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L375
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L371
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L511
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L261
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L257
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L59
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L929
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L926
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L917
# Metadata: ConvoKitMeta({'movie_idx': 'm0', 'movie_name': '10 things i hate about you', 'release_year': '1999', 'rating': '6.90', 'votes': '62847', 'genre': "['comedy', 'romance']"})
# ...
#
# Conversation ID: L187550
# Metadata: ConvoKitMeta({'movie_idx': 'm54', 'movie_name': 'erik the viking', 'release_year': '1989', 'rating': '5.90', 'votes': '5889', 'genre': "['comedy', 'adventure', 'fantasy']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L194855
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194849
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L194846
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194823
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L194401
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194397
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194393
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194883
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194870
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L194424
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194077
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194075
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194051
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194636
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194573
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194571
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194551
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L194547
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L194332
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194326
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L194323
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194088
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194085
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194081
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L195097
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L195060
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 13
#
# Conversation ID: L195033
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 13
#
# Conversation ID: L195031
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L195029
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L195025
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194995
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L194946
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194941
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L194936
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194931
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L194927
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194922
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194919
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194917
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194914
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194911
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194894
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 17
#
# Conversation ID: L194888
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L194885
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194881
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194877
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194874
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194865
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L194862
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L194814
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L194804
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 9
#
# Conversation ID: L194786
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194765
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L194762
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L194755
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L194743
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L194687
# Metadata: ConvoKitMeta({'movie_idx': 'm55', 'movie_name': 'eternal sunshine of the spotless mind', 'release_year': '2004', 'rating': '8.50', 'votes': '224838', 'genre': "['drama', 'romance', 'sci-fi']"})
# Number of utterances in conversation:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# Create empty lists to store data
conversation_ids = []
movie_indices = []
movie_names = []
release_years = []
ratings = []
votes = []
genres = []
num_utterances = []

# Loop through conversations and extract data
for convo_id in corpus.get_conversation_ids():
    convo = corpus.get_conversation(convo_id)

    # Extract metadata from ConvoKitMeta object
    metadata = convo.meta

    # Append data to respective lists
    conversation_ids.append(convo_id)
    movie_indices.append(metadata['movie_idx'])
    movie_names.append(metadata['movie_name'])
    release_years.append(metadata['release_year'])
    ratings.append(metadata['rating'])
    votes.append(metadata['votes'])
    genres.append(metadata['genre'])
    num_utterances.append(len(convo.get_utterance_ids()))

# Create a DataFrame from the lists
data = {
    'Conversation ID': conversation_ids,
    'Movie Index': movie_indices,
    'Movie Name': movie_names,
    'Rating': ratings,
}

df = pd.DataFrame(data)

# %%
df
# Out:
#       Conversation ID Movie Index                  Movie Name Rating
# 0               L1044          m0  10 things i hate about you   6.90
# 1                L984          m0  10 things i hate about you   6.90
# 2                L924          m0  10 things i hate about you   6.90
# 3                L870          m0  10 things i hate about you   6.90
# 4                L866          m0  10 things i hate about you   6.90
# ...               ...         ...                         ...    ...
# 83092         L666324        m616                   zulu dawn   6.40
# 83093         L666262        m616                   zulu dawn   6.40
# 83094         L666520        m616                   zulu dawn   6.40
# 83095         L666369        m616                   zulu dawn   6.40
# 83096         L666256        m616                   zulu dawn   6.40
#
# [83097 rows x 4 columns]

# %%
# Create a Reader object specifying the rating scale
reader = Reader(rating_scale=(1, 10))

# %%
# Load the dataset into Surprise format
data = df[['Conversation ID','Movie Name','Rating']]
data = Dataset.load_from_df(data, reader)

# Split the data into training and testing sets (80% train, 20% test)
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# Create and train the SVD recommendation model
model = SVD()
model.fit(trainset)

# Evaluate the model on the testing data (calculate RMSE)
predictions = model.test(testset)
rmse = accuracy.rmse(predictions)
# Out:
# RMSE: 0.0630

# %%
# Generate recommendations for a specific user (e.g., user_id='L236416')
user_id = 'L36547'
user_movies = df[df['Conversation ID'] == user_id]['Movie Name'].unique()

# Create a list of unrated movies for the user
all_movies = df['Movie Name'].unique()
unrated_movies = np.setdiff1d(all_movies, user_movies)

# Generate predictions for unrated movies
user_recommendations = []
for movie_id in unrated_movies:
    predicted_rating = model.predict(user_id, movie_id).est
    user_recommendations.append((movie_id, predicted_rating))

    # Sort recommendations by predicted rating (highest first)
user_recommendations.sort(key=lambda x: x[1], reverse=True)

# %%
# Display the top n recommendations
top_n = 3
print(f'Top {top_n} recommendations for user {user_id}:')
for movie_id, predicted_rating in user_recommendations[:top_n]:
    print(f'Movie ID: {movie_id}, Predicted Rating: {predicted_rating:.2f}')
# Out:
# Top 3 recommendations for user L36547:
# Movie ID: the godfather, Predicted Rating: 9.12
# Movie ID: neuromancer, Predicted Rating: 9.08
# Movie ID: the godfather: part ii, Predicted Rating: 8.82
